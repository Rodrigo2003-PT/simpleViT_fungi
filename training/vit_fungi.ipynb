# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
import sys
import json
import gc
import zipfile
from pathlib import Path
from typing import Dict, List
from collections import Counter

import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
from numpy.random import SeedSequence

from sklearn.metrics import (
    precision_recall_fscore_support,
    balanced_accuracy_score,
    matthews_corrcoef,
    f1_score,
    roc_auc_score,
)

from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
experiment_name = "standard"

drive_project_path = "/content/drive/MyDrive/colab/vit_fungi"
drive_scripts_path = os.path.join(drive_project_path, "scripts")
drive_preprocessed_zip = os.path.join(drive_project_path, "preprocessed", "preprocessed_384.zip")
drive_split_indices = os.path.join(drive_project_path, "preprocessed", "split_indices.json")

exp_suffix = experiment_name
drive_output_path = os.path.join(drive_project_path, "output", exp_suffix)
drive_checkpoint_path = os.path.join(drive_project_path, "checkpoints", exp_suffix)

local_preprocessed_path = "/content/data"
local_scripts_path = "/content/scripts"
local_checkpoint_path = os.path.join("/content/checkpoints", exp_suffix)

for p in [
    local_preprocessed_path,
    local_scripts_path,
    local_checkpoint_path,
    drive_output_path,
    drive_checkpoint_path,
]:
    os.makedirs(p, exist_ok=True)

# %%
get_ipython().system("pip install -q vit-pytorch")
get_ipython().system(f"cp -r {drive_scripts_path}/* {local_scripts_path}/")
sys.path.insert(0, local_scripts_path)

from checkpoints import CheckpointManager, initialize_master_state
from plotting_utils import TrainingPlotter
from training_logic import ModelTrainer, determine_optimal_epochs
from training_utils import (
    NPYImageFolder,
    calculate_dataset_stats,
    create_transforms,
    calculate_class_weights,
    grouped_bootstrap_ci,
    aggregate_predictions_by_group,
    create_data_loaders,
    print_data_distribution,
    verify_data_splits,
    get_device_info,
    TransformSubset,
    create_slide_level_folds,
    validate_split_quality

)
from config import get_config, save_config
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.3/165.3 kB 10.6 MB/s eta 0:00:00

# %%
config = get_config(experiment_name)
save_config(config, drive_output_path)

n_iterations = int(config["n_iterations"])
n_folds = int(config["n_folds"])
base_seed = int(config["random_seed"])

checkpoint_manager = CheckpointManager(
    local_checkpoint_dir=local_checkpoint_path,
    drive_checkpoint_dir=drive_checkpoint_path,
    n_folds=n_folds,
)

plotter = TrainingPlotter(drive_output_path, dpi=300)

checkpoint_manager.cleanup_temp_files(verbose=True)
checkpoint_manager.sync_from_drive(verbose=True)

device = get_device_info()

preprocessed_dir = os.path.join(local_preprocessed_path, "preprocessed")

if not os.path.exists(preprocessed_dir):
    if not os.path.exists(drive_preprocessed_zip):
        raise FileNotFoundError(f"Preprocessed data not found at: {drive_preprocessed_zip}")
    with zipfile.ZipFile(drive_preprocessed_zip, "r") as zf:
        zf.extractall(local_preprocessed_path)
else:
    print(f"Using existing preprocessed data at: {preprocessed_dir}")

metadata: Dict = {}
metadata_path = os.path.join(preprocessed_dir, "metadata.json")
if os.path.exists(metadata_path):
    with open(metadata_path, "r") as f:
        metadata = json.load(f)
    print(f"Loaded metadata from: {os.path.basename(metadata_path)}")
else:
    print("WARNING: metadata.json not found; using minimal metadata.")
    metadata = {
        "method": "unknown",
        "bit_depth": None,
        "image_size": config.get("image_size", None),
        "n_channels": config.get("channels", 1),
    }

# Consistency checks (preserve logic)
cfg_bit = config.get("bit_depth", None)
meta_bit = metadata.get("bit_depth", None)
if cfg_bit is not None and meta_bit is not None and cfg_bit != meta_bit:
    print(f"WARNING: config bit_depth={cfg_bit} but preprocessing bit_depth={meta_bit}.")

meta_size = metadata.get("image_size", None)
cfg_size = config.get("image_size", None)
if meta_size is not None and cfg_size is not None and meta_size != cfg_size:
    print(f"WARNING: config image_size={cfg_size} but preprocessing image_size={meta_size}.")
# Out:
#   Config saved to: /content/drive/MyDrive/colab/vit_fungi/output/standard/config_standard.json
#   Synced: cv_iter_28_fold_3_checkpoint.pth
#   Synced: master_training_state.json
# Sync complete: 2 file(s) updated
#
# Device Information:
#   Device: cuda
#   GPU: Tesla T4
#   Memory: 15.83 GB
#   CUDA Version: 12.6
# Loaded metadata from: metadata.json

# %%
if not os.path.exists(drive_split_indices):
    raise FileNotFoundError(f"Split indices not found at: {drive_split_indices}")

with open(drive_split_indices, "r") as f:
    split_data = json.load(f)

train_base_paths = [Path(p) for p in split_data["train_base_paths"]]
test_base_paths = [Path(p) for p in split_data["test_base_paths"]]
class_names = split_data["classes"]

print("Classes:", class_names)
print("Train images:", len(train_base_paths))
print("Test images:", len(test_base_paths))

dataset = NPYImageFolder(preprocessed_dir)
num_classes = len(dataset.classes)

labels = np.array(dataset.targets)

print("Total images:", len(dataset))
print("Num classes:", num_classes)
print("Dataset classes:", dataset.classes)

npy_base_to_idx: Dict[str, int] = {}
idx_to_base: Dict[int, Path] = {}

for idx, (sample_path, target) in enumerate(dataset.samples):
    rel_npy = Path(sample_path).relative_to(preprocessed_dir)
    base_npy = rel_npy.with_suffix("")
    npy_base_to_idx[base_npy.as_posix()] = idx
    idx_to_base[idx] = Path(base_npy)

train_val_idx: List[int] = []
test_idx: List[int] = []

for base in train_base_paths:
    key = base.as_posix()
    if key not in npy_base_to_idx:
        raise RuntimeError(f"Train base path not found in dataset mapping: {key}")
    train_val_idx.append(npy_base_to_idx[key])

for base in test_base_paths:
    key = base.as_posix()
    if key not in npy_base_to_idx:
        raise RuntimeError(f"Test base path not found in dataset mapping: {key}")
    test_idx.append(npy_base_to_idx[key])

print("TrainVal indices:", len(train_val_idx))
print("Test indices:", len(test_idx))

verify_data_splits(train_val_idx, [], test_idx)
print_data_distribution(labels[train_val_idx].tolist(), dataset.classes, "TrainVal")
print_data_distribution(labels[test_idx].tolist(), dataset.classes, "Test")
# Out:
# Classes: ['Candida albicans', 'Candida glabrata']
# Train images: 2910
# Test images: 821
# NPYImageFolder initialized: 3763 samples (grayscale)
# Total images: 3763
# Num classes: 2
# Dataset classes: ['Candida albicans', 'Candida glabrata']
# TrainVal indices: 2910
# Test indices: 821
# ✓ Data splits verified: No overlap detected
#
# TrainVal Distribution:
#   Total samples: 2910
#   Candida albicans: 1616 (55.5%)
#   Candida glabrata: 1294 (44.5%)
#
# Test Distribution:
#   Total samples: 821
#   Candida albicans: 440 (53.6%)
#   Candida glabrata: 381 (46.4%)

# %%
def extract_slide_id_from_base(p: Path) -> str:
    stem = p.name
    parts = stem.split("_")
    if len(parts) < 3:
        return stem
    date, species_code, letter = parts[0], parts[1], parts[2]
    return f"{date}_{species_code}_{letter}"

all_groups = np.empty(len(dataset), dtype=object)
for idx in range(len(dataset)):
    base_path = idx_to_base[idx]
    slide_id = extract_slide_id_from_base(base_path)
    all_groups[idx] = slide_id

test_groups = all_groups[test_idx]

def run_cross_validation(master_state: Dict) -> None:
    """
    Cross-validation with SLIDE-LEVEL stratification.
    """
    print("-" * 70)
    print("PHASE: CROSS-VALIDATION (Slide-Level Stratification)")
    print("-" * 70)
    print(f"Base seed: {base_seed}")

    start_iteration = int(master_state.get("current_iteration", 0))
    start_fold = int(master_state.get("current_fold", 0))
    cv_fold_details = list(master_state.get("cv_fold_details", []))

    trainer = ModelTrainer(config, device, checkpoint_manager, num_classes)

    ss = SeedSequence(base_seed)
    iteration_seed_gens = ss.spawn(n_iterations)
    iteration_seeds_base = [int(g.generate_state(1)[0]) for g in iteration_seed_gens]

    trainval_idx_np = np.array(train_val_idx)

    for iter_idx in range(start_iteration, n_iterations):
        iteration_seed_base = iteration_seeds_base[iter_idx]
        print("\n" + "=" * 70)
        print(f"ITERATION {iter_idx + 1}/{n_iterations} | base seed {iteration_seed_base}")
        print("=" * 70)

        min_slides_per_class = config.get("min_slides_per_class_validation", 2)
        min_slide_balance_ratio = config.get("min_slide_balance_ratio", 0.4)
        max_image_imbalance_ratio = config.get("max_image_imbalance_ratio", 0.2)

        try:
            fold_splits, split_metadata = create_slide_level_folds(
                image_indices=trainval_idx_np,
                image_labels=labels,
                slide_groups=all_groups,
                n_splits=n_folds,
                random_state=iteration_seed_base,
                class_names=dataset.classes,
                min_slides_per_class=min_slides_per_class,
                min_slide_balance_ratio=min_slide_balance_ratio,
                max_image_imbalance_ratio=max_image_imbalance_ratio,
                max_retries=50,
                verbose=True
            )

            iteration_seed_effective = split_metadata['random_state_effective']
            retry_count = split_metadata['retry_count']

            print(f"  Effective seed: {iteration_seed_effective}")
            if retry_count > 0:
                print(f"  Required {retry_count} {'retry' if retry_count == 1 else 'retries'}")

        except RuntimeError as e:
            print(f"\n FATAL ERROR: Could not create valid slide-stratified folds")
            print(f"\n{e}")
            print(f"\nAborting iteration {iter_idx + 1}. Please review dataset and constraints.")

            master_state["current_iteration"] = iter_idx
            master_state["current_fold"] = 0
            master_state["split_error"] = str(e)
            checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
            return

        if "split_metadata_per_iteration" not in master_state:
            master_state["split_metadata_per_iteration"] = {}

        master_state["split_metadata_per_iteration"][iter_idx] = {
            "iteration_seed_base": int(iteration_seed_base),
            "iteration_seed_effective": int(iteration_seed_effective),
            "retry_count": int(retry_count),
            "n_folds": n_folds,
            "min_slides_per_class": min_slides_per_class,
            "min_slide_balance_ratio": min_slide_balance_ratio,
            "fold_quality_stats": [
                {
                    'fold_idx': meta['fold_idx'],
                    'val_n_slides': meta['val_stats']['n_slides'],
                    'val_n_images': meta['val_stats']['n_images'],
                    'val_slide_balance': meta['val_stats']['slide_balance_ratio'],
                    'val_image_balance': meta['val_stats']['image_balance_ratio'],
                    'val_slides_per_class': meta['val_stats']['slides_per_class']
                }
                for meta in split_metadata['fold_metadata']
            ]
        }

        for fold_idx, (cv_train_global, cv_val_global) in enumerate(fold_splits):
            if iter_idx == start_iteration and fold_idx < start_fold:
                continue

            print(f"Fold {fold_idx + 1}/{n_folds}")

            # Get fold statistics from metadata
            fold_meta = split_metadata['fold_metadata'][fold_idx]
            train_stats = fold_meta['train_stats']
            val_stats = fold_meta['val_stats']

            # Quality assurance check
            is_valid, error_msg = validate_split_quality(
                train_stats, val_stats, dataset.classes,
                min_slides_per_class, min_slide_balance_ratio, max_image_imbalance_ratio
            )

            if not is_valid:
                raise RuntimeError(
                    f"Split validation failed for Iter {iter_idx+1} Fold {fold_idx+1}.\n"
                    f"This indicates a bug in create_slide_level_folds.\n"
                    f"Error: {error_msg}"
                )

            print(f"\nCalculating normalization statistics from training set...")
            fold_mean, fold_std = calculate_dataset_stats(
                dataset=dataset,
                indices=cv_train_global.tolist(),
                batch_size=int(config["batch_size"]),
                num_workers=int(config["num_workers"]),
            )
            print(f"  Mean: {[f'{x:.4f}' for x in fold_mean]}")
            print(f"  Std:  {[f'{x:.4f}' for x in fold_std]}")

            # Create data loaders
            train_transform = create_transforms(fold_mean, fold_std, config, train=True)
            val_transform = create_transforms(fold_mean, fold_std, config, train=False)

            train_loader, val_loader = create_data_loaders(
                dataset=dataset,
                train_indices=cv_train_global.tolist(),
                val_indices=cv_val_global.tolist(),
                train_transform=train_transform,
                val_transform=val_transform,
                batch_size=int(config["batch_size"]),
                num_workers=int(config["num_workers"]),
            )

            fold_class_weights = calculate_class_weights(
                targets=labels[cv_train_global].tolist(),
                num_classes=num_classes,
                device=device,
                gamma=float(config.get("class_weight_gamma", 1.0)),
            )

            val_groups_fold = all_groups[cv_val_global]

            if val_groups_fold is None or len(val_groups_fold) == 0:
                raise RuntimeError(
                    f"No slide groups found for validation fold {fold_idx+1}. "
                )

            print(f"\nTraining fold {fold_idx + 1}...")
            fold_summary = trainer.train_cv_fold(
                iter_idx=iter_idx,
                fold_idx=fold_idx,
                iteration_seed=int(iteration_seed_effective),
                train_loader=train_loader,
                val_loader=val_loader,
                fold_mean=fold_mean,
                fold_std=fold_std,
                class_weights=fold_class_weights,
                val_groups_fold=val_groups_fold,
            )

            fold_summary["iteration_seed_base"] = int(iteration_seed_base)
            fold_summary["iteration_seed_effective"] = int(iteration_seed_effective)
            fold_summary["split_retry_count"] = int(retry_count)
            fold_summary["val_slides_per_class"] = val_stats['slides_per_class']
            fold_summary["val_slide_balance_ratio"] = val_stats['slide_balance_ratio']
            fold_summary["val_image_balance_ratio"] = val_stats['image_balance_ratio']

            cv_fold_details.append(fold_summary)

            master_state["cv_fold_details"] = cv_fold_details
            master_state["current_iteration"] = iter_idx
            master_state["current_fold"] = fold_idx + 1

            if fold_idx + 1 >= n_folds:
                master_state["current_iteration"] = iter_idx + 1
                master_state["current_fold"] = 0

            checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
            checkpoint_manager.cleanup_previous_fold_checkpoint(iter_idx, fold_idx, verbose=True)

            del train_loader, val_loader, fold_class_weights
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        start_fold = 0

    master_state["all_iterations_completed"] = True
    master_state["phase"] = "analysis"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("\n" + "=" * 70)
    print("CROSS-VALIDATION COMPLETE")
    print("=" * 70)
    print(f"\nCompleted {n_iterations} iterations × {n_folds} folds")
    print(f"Total fold summaries: {len(cv_fold_details)}")
    print(f"\nNext phase: Analysis")
    print("=" * 70 + "\n")

# %%
def run_analysis(master_state: Dict) -> None:
    print("-" * 70)
    print("PHASE: ANALYSIS")
    print("-" * 70)

    cv_fold_details = master_state.get("cv_fold_details", [])
    if not cv_fold_details:
        print("ERROR: No CV fold details found in master_state.")
        return

    cv_results_df = pd.DataFrame(cv_fold_details)
    n_folds_total = len(cv_results_df)
    n_iters_found = cv_results_df["iteration"].nunique() if "iteration" in cv_results_df.columns else None
    print(f"Loaded {n_folds_total} fold summaries | iterations={n_iters_found}")

    # Save CSV locally + backup to Drive
    results_csv_path = checkpoint_manager.get_results_csv_path(config["experiment_name"], use_local=True)
    cv_results_df.to_csv(results_csv_path, index=False)
    print(f"CV results saved to: {results_csv_path}")

    drive_csv_path = checkpoint_manager.get_results_csv_path(config["experiment_name"], use_local=False)
    try:
        import shutil

        shutil.copy2(results_csv_path, drive_csv_path)
        print(f"Backed up to Drive: {drive_csv_path}")
    except Exception as e:
        print(f"WARNING: Could not backup CSV to Drive: {e}")

    plotter.plot_iteration_results(
        cv_results_df,
        experiment_name=config["experiment_name"],
        save_name=f"cv_iteration_results_{config['experiment_name']}.png",
        show=False,
        prefer_slide_level=True,
    )

    print("Determining optimal number of epochs...")
    optimal_epochs = determine_optimal_epochs(
        cv_fold_details=cv_results_df.to_dict("records"),
        method="median",
        config=config,
    )
    print("Selected optimal_epochs:", optimal_epochs)

    master_state["optimal_epochs"] = int(optimal_epochs)
    
    master_state["phase"] = "final_training"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("-" * 70)
    print("ANALYSIS COMPLETE")
    print("-" * 70)

# %%
def run_final_training(master_state: Dict) -> None:
    print("-" * 70)
    print("PHASE: FINAL TRAINING")
    print("-" * 70)

    optimal_epochs = int(master_state.get("optimal_epochs", config.get("num_epochs", 50)))
    print(f"Training final model for {optimal_epochs} epochs")

    print("Calculating normalization statistics on full training set...")
    final_mean, final_std = calculate_dataset_stats(
        dataset=dataset,
        indices=train_val_idx,
        batch_size=int(config["batch_size"]),
        num_workers=int(config["num_workers"]),
    )
    print("Final mean:", final_mean)
    print("Final std:", final_std)

    train_transform = create_transforms(final_mean, final_std, config, train=True)
    final_dataset = TransformSubset(dataset, list(train_val_idx), train_transform)

    final_loader = torch.utils.data.DataLoader(
        final_dataset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=int(config["num_workers"]),
        pin_memory=True,
    )

    final_class_weights = calculate_class_weights(
        targets=labels[train_val_idx],
        num_classes=num_classes,
        device=device,
        gamma=float(config.get("class_weight_gamma", 1.0)),
    )

    trainer = ModelTrainer(config, device, checkpoint_manager, num_classes)
    final_model, final_training_history = trainer.train_final_model(
        train_loader=final_loader,
        optimal_epochs=optimal_epochs,
        final_mean=final_mean,
        final_std=final_std,
        class_weights=final_class_weights,
    )

    final_model_save_path = os.path.join(drive_output_path, f"final_model_{config['experiment_name']}.pth")
    torch.save(
        {
            "model_state_dict": final_model.state_dict(),
            "config": config,
            "mean": final_mean,
            "std": final_std,
            "class_to_idx": dataset.class_to_idx,
            "optimal_epochs": int(optimal_epochs),
            "training_history": final_training_history,
            "metadata": metadata,
        },
        final_model_save_path,
    )
    print(f"Final model saved to: {final_model_save_path}")

    plotter.plot_training_curves(
        final_training_history,
        title=f"Final Model Training - {config['experiment_name']}",
        save_name=f"final_model_training_curves_{config['experiment_name']}.png",
        show=False,
    )

    master_state["final_training_completed"] = True
    master_state["phase"] = "evaluation"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("-" * 70)
    print("FINAL TRAINING COMPLETE")
    print("-" * 70)

# %%
def run_evaluation(master_state: Dict) -> None:
    """
    Evaluate final model on held-out test set with proper slide-level aggregation.
    """
    print("\n" + "="*70)
    print("PHASE: TEST SET EVALUATION")
    print("="*70 + "\n")

    # Load final model
    final_model_path = os.path.join(
        drive_output_path,
        f"final_model_{config['experiment_name']}.pth"
    )

    if not os.path.exists(final_model_path):
        print(f"ERROR: Final model not found at {final_model_path}")
        return

    print(f"  Loading final model from {os.path.basename(final_model_path)}")
    checkpoint = torch.load(final_model_path, map_location=device)

    # Create model
    from vit_pytorch import SimpleViT

    model = SimpleViT(
        image_size=config["image_size"],
        patch_size=config["patch_size"],
        num_classes=num_classes,
        **config["model_config"],
    ).to(device)

    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    print("  Model loaded successfully")

    # Create test loader
    test_mean = checkpoint["mean"]
    test_std = checkpoint["std"]
    test_transform = create_transforms(test_mean, test_std, config, train=False)

    _, test_loader = create_data_loaders(
        dataset,
        train_indices=[],
        val_indices=test_idx,
        train_transform=None,
        val_transform=test_transform,
        batch_size=config["batch_size"],
        num_workers=config["num_workers"],
    )

    # Run inference
    all_preds = []
    all_labels = []
    all_probs_list = []

    print(f"  Running inference on {len(test_idx)} test samples...")
    with torch.inference_mode():
        for X, y in tqdm(test_loader, desc="Testing", ncols=80, leave=False):
            X = X.to(device)
            logits = model(X)
            probs = logits.softmax(dim=1)
            all_preds.extend(logits.argmax(1).cpu().numpy())
            all_probs_list.append(probs.cpu().numpy())
            all_labels.extend(y.cpu().numpy())
    print("  Inference complete")

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    all_probs = np.vstack(all_probs_list)

    # ------------------------------------------------------------------
    # 1) IMAGE-LEVEL METRICS (Patch-based)
    # ------------------------------------------------------------------
    print("\n  Computing image-level metrics...")
    test_bal_acc = balanced_accuracy_score(all_labels, all_preds)
    test_mcc = matthews_corrcoef(all_labels, all_preds)
    test_f1 = f1_score(all_labels, all_preds, average="weighted", zero_division=0)
    test_auc = roc_auc_score(all_labels, all_probs[:, 1])

    print("  Calculating 95% confidence intervals (1000 bootstrap) - image level...")
    bal_acc_ci = grouped_bootstrap_ci(
        balanced_accuracy_score,
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=42,
        verbose=False,
    )
    mcc_ci = grouped_bootstrap_ci(
        matthews_corrcoef,
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=43,
        verbose=False,
    )
    f1_ci = grouped_bootstrap_ci(
        lambda y_true, y_pred: f1_score(y_true, y_pred, average="weighted", zero_division=0),
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=44,
        verbose=False,
    )
    auc_ci = grouped_bootstrap_ci(
        lambda y_true, p_hat: roc_auc_score(y_true, p_hat[:, 1]),
        [all_labels, all_probs],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=45,
        verbose=False,
    )

    # ------------------------------------------------------------------
    # 2) SLIDE-LEVEL AGGREGATION AND METRICS
    # ------------------------------------------------------------------
    print("\n  Aggregating predictions to slide level...")
    (
        slide_true,
        slide_pred,
        slide_proba,
        slide_ids,
    ) = aggregate_predictions_by_group(
        y_true=all_labels,
        y_pred=all_preds,
        y_proba=all_probs,
        groups=test_groups,
        num_classes=num_classes,
    )

    print(f"  Aggregated {len(all_labels)} images into {len(slide_true)} slides")

    # Slide-level metrics
    slide_bal_acc = balanced_accuracy_score(slide_true, slide_pred)
    slide_mcc = matthews_corrcoef(slide_true, slide_pred)
    slide_f1 = f1_score(slide_true, slide_pred, average="weighted", zero_division=0)
    slide_auc = roc_auc_score(slide_true, slide_proba[:, 1])

    print("  Calculating 95% confidence intervals (1000 bootstrap) - slide level...")
    slide_groups_dummy = np.arange(len(slide_true))  # Each slide is its own group

    slide_bal_acc_ci = grouped_bootstrap_ci(
        balanced_accuracy_score,
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=52,
        verbose=False,
    )
    slide_mcc_ci = grouped_bootstrap_ci(
        matthews_corrcoef,
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=53,
        verbose=False,
    )
    slide_f1_ci = grouped_bootstrap_ci(
        lambda y_true, y_pred: f1_score(y_true, y_pred, average="weighted", zero_division=0),
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=54,
        verbose=False,
    )
    slide_auc_ci = grouped_bootstrap_ci(
        lambda y_true, p_hat: roc_auc_score(y_true, p_hat[:, 1]),
        [slide_true, slide_proba],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=55,
        verbose=False,
    )

    # ------------------------------------------------------------------
    # 3) PER-CLASS METRICS (Both levels)
    # ------------------------------------------------------------------
    print("\n  Computing per-class metrics...")

    # Image-level per-class
    p_img, r_img, f1_img, s_img = precision_recall_fscore_support(
        all_labels,
        all_preds,
        labels=list(range(num_classes)),
        average=None,
        zero_division=0,
    )

    per_class_metrics_image = {}
    for i, class_name in enumerate(dataset.classes):
        per_class_metrics_image[class_name] = {
            "precision": float(p_img[i]),
            "recall": float(r_img[i]),
            "f1_score": float(f1_img[i]),
            "support": int(s_img[i]),
        }

    # Slide-level per-class
    p_slide, r_slide, f1_slide, s_slide = precision_recall_fscore_support(
        slide_true,
        slide_pred,
        labels=list(range(num_classes)),
        average=None,
        zero_division=0,
    )

    per_class_metrics_slide = {}
    for i, class_name in enumerate(dataset.classes):
        per_class_metrics_slide[class_name] = {
            "precision": float(p_slide[i]),
            "recall": float(r_slide[i]),
            "f1_score": float(f1_slide[i]),
            "support": int(s_slide[i]),
        }

    # ------------------------------------------------------------------
    # 4) PRINT SUMMARY
    # ------------------------------------------------------------------
    print("\n" + "="*70)
    print("TEST SET RESULTS SUMMARY")
    print("="*70)

    print("\nIMAGE-LEVEL METRICS (Patch-based):")
    print(f"  Balanced Accuracy: {test_bal_acc:.4f} (95% CI: [{bal_acc_ci[0]:.4f}, {bal_acc_ci[1]:.4f}])")
    print(f"  MCC:               {test_mcc:.4f} (95% CI: [{mcc_ci[0]:.4f}, {mcc_ci[1]:.4f}])")
    print(f"  F1-Score:          {test_f1:.4f} (95% CI: [{f1_ci[0]:.4f}, {f1_ci[1]:.4f}])")
    print(f"  AUC:               {test_auc:.4f} (95% CI: [{auc_ci[0]:.4f}, {auc_ci[1]:.4f}])")

    print("\nSLIDE-LEVEL METRICS (Aggregated):")
    print(f"  Balanced Accuracy: {slide_bal_acc:.4f} (95% CI: [{slide_bal_acc_ci[0]:.4f}, {slide_bal_acc_ci[1]:.4f}])")
    print(f"  MCC:               {slide_mcc:.4f} (95% CI: [{slide_mcc_ci[0]:.4f}, {slide_mcc_ci[1]:.4f}])")
    print(f"  F1-Score:          {slide_f1:.4f} (95% CI: [{slide_f1_ci[0]:.4f}, {slide_f1_ci[1]:.4f}])")
    print(f"  AUC:               {slide_auc:.4f} (95% CI: [{slide_auc_ci[0]:.4f}, {slide_auc_ci[1]:.4f}])")

    print("\nPER-CLASS METRICS:")
    for class_name in dataset.classes:
        img_metrics = per_class_metrics_image[class_name]
        slide_metrics = per_class_metrics_slide[class_name]
        print(f"\n  {class_name}:")
        print(f"    Image-level: P={img_metrics['precision']:.3f}, R={img_metrics['recall']:.3f}, "
              f"F1={img_metrics['f1_score']:.3f} (n={img_metrics['support']} images)")
        print(f"    Slide-level: P={slide_metrics['precision']:.3f}, R={slide_metrics['recall']:.3f}, "
              f"F1={slide_metrics['f1_score']:.3f} (n={slide_metrics['support']} slides)")

    print("="*70 + "\n")

    # ------------------------------------------------------------------
    # 5) VISUALIZATIONS
    # ------------------------------------------------------------------
    print("  Generating visualizations...")

    # Confusion matrix (image-level)
    plotter.plot_confusion_matrix(
        all_labels,
        all_preds,
        dataset.classes,
        title="Test Set Confusion Matrix (Image-Level)",
        save_name=f"confusion_matrix_image_{config['experiment_name']}.png",
        normalize=True,
        show=False
    )

    # Confusion matrix (slide-level)
    plotter.plot_confusion_matrix(
        slide_true,
        slide_pred,
        dataset.classes,
        title="Test Set Confusion Matrix (Slide-Level)",
        save_name=f"confusion_matrix_slide_{config['experiment_name']}.png",
        normalize=True,
        show=False
    )

    # ROC curve (image-level)
    plotter.plot_roc_auc_curves(
        all_labels,
        all_probs,
        title=f"ROC Curve (Image-Level) - {config['experiment_name']}",
        save_name=f"roc_auc_curve_image_{config['experiment_name']}.png",
        show=False
    )

    # ROC curve (slide-level)
    plotter.plot_roc_auc_curves(
        slide_true,
        slide_proba,
        title=f"ROC Curve (Slide-Level) - {config['experiment_name']}",
        save_name=f"roc_auc_curve_slide_{config['experiment_name']}.png",
        show=False
    )

    # ------------------------------------------------------------------
    # 6) SAVE RESULTS
    # ------------------------------------------------------------------
    test_results_data = {
        "experiment_name": config["experiment_name"],
        "metadata": metadata,

        # Image-level metrics
        "overall_metrics_image_level": {
            "balanced_accuracy": float(test_bal_acc),
            "mcc": float(test_mcc),
            "f1_score_weighted": float(test_f1),
            "auc_binary": float(test_auc),
        },
        "confidence_intervals_95_image_level": {
            "balanced_accuracy": (float(bal_acc_ci[0]), float(bal_acc_ci[1])),
            "mcc": (float(mcc_ci[0]), float(mcc_ci[1])),
            "f1_score_weighted": (float(f1_ci[0]), float(f1_ci[1])),
            "auc_binary": (float(auc_ci[0]), float(auc_ci[1])),
        },

        # Slide-level metrics
        "overall_metrics_slide_level": {
            "balanced_accuracy": float(slide_bal_acc),
            "mcc": float(slide_mcc),
            "f1_score_weighted": float(slide_f1),
            "auc_binary": float(slide_auc),
        },
        "confidence_intervals_95_slide_level": {
            "balanced_accuracy": (float(slide_bal_acc_ci[0]), float(slide_bal_acc_ci[1])),
            "mcc": (float(slide_mcc_ci[0]), float(slide_mcc_ci[1])),
            "f1_score_weighted": (float(slide_f1_ci[0]), float(slide_f1_ci[1])),
            "auc_binary": (float(slide_auc_ci[0]), float(slide_auc_ci[1])),
        },

        # Per-class metrics
        "per_class_metrics_image_level": per_class_metrics_image,
        "per_class_metrics_slide_level": per_class_metrics_slide,

        # Dataset sizes
        "test_set_size_images": len(test_idx),
        "test_set_size_slides": int(len(np.unique(test_groups))),

        # Additional metadata
        "unique_test_slides": sorted([str(sid) for sid in np.unique(test_groups)]),
    }

    results_json_path = os.path.join(
        drive_output_path,
        f"test_results_{config['experiment_name']}.json"
    )

    with open(results_json_path, 'w') as f:
        json.dump(test_results_data, f, indent=4)

    print(f"\n  Results saved to: {os.path.basename(results_json_path)}")
    checkpoint_manager.cleanup_fold_histories(verbose=True)

    # Update master state
    master_state["phase"] = "completed"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("\n" + "="*70)
    print("EVALUATION COMPLETE")
    print("="*70 + "\n")

# %%
def main() -> None:
    master_state = checkpoint_manager.load_master_state(prefer_drive=True)
    if master_state is None:
        print("No previous training state found. Initializing new state...")
        master_state = initialize_master_state()
        checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
        print("Master state initialized")
    else:
        print(f"Resuming from saved state | phase={master_state.get('phase', 'unknown')}")

    try:
        phase = master_state.get("phase", "cross_validation")

        if phase == "cross_validation":
            run_cross_validation(master_state)
            phase = "analysis"

        if phase == "analysis":
            run_analysis(master_state)
            phase = "final_training"

        if phase == "final_training":
            run_final_training(master_state)
            phase = "evaluation"

        if phase == "evaluation":
            run_evaluation(master_state)
            phase = "completed"

        if phase == "completed":
            print("-" * 70)
            print("PIPELINE COMPLETED SUCCESSFULLY")
            print("-" * 70)
            print("Experiment:", config["experiment_name"])
            print("Results:", drive_output_path)

    except KeyboardInterrupt:
        print("Training interrupted by user.")
        print("Current phase:", master_state.get("phase", "unknown"))
        print("State saved - run again to resume.")
    except Exception as e:
        print(f"ERROR: {e}")
        import traceback

        traceback.print_exc()
        print("Current phase:", master_state.get("phase", "unknown"))
        print("State saved - fix error and run again to resume.")


if __name__ == "__main__":
    main()
# Out:
# Loaded master state from: master_training_state.json
# Resuming from saved state | phase=cross_validation
# ----------------------------------------------------------------------
# PHASE: CROSS-VALIDATION (Slide-Level Stratification)
# ----------------------------------------------------------------------
# Base seed: 42
# MixUp enabled: alpha=0.2, prob=0.5
#
# ======================================================================
# ITERATION 29/30 | base seed 168388230
# ======================================================================
#
# ✓ Valid splits found on first attempt
#   Effective seed: 168388230
# Fold 5/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2368']
#   Std:  ['0.0075']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 5...
#
# ======================================================================
# ITERATION 29/30 | FOLD 5/5
# Iteration Seed: 168388230
# Validation: ~9 slides, 528 patches
# Starting fold from scratch
# Model initialization seed: 3636547837
#   Model created with seed 3636547837: 5,325,058 params (5,325,058 trainable)
#
#  BEST MODEL at epoch 1 (reason: first_epoch)
#    slide_BA: 0.5000 | val_loss: 0.6825
# Iter 29, Fold 5, Epoch 1/100 | train_loss: 0.6995 | train_acc: 0.5202
#   PATCH-level: val_loss=0.6825, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6825
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000120
# Iter 29, Fold 5, Epoch 2/100 | train_loss: 0.6924 | train_acc: 0.5344
#   PATCH-level: val_loss=0.6911, bal_acc=0.5106
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6825
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000180
# Iter 29, Fold 5, Epoch 3/100 | train_loss: 0.6941 | train_acc: 0.5453
#   PATCH-level: val_loss=0.7424, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6825
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000240
#
#  BEST MODEL at epoch 4 (reason: better_slide_ba)
#    slide_BA: 0.6000 | val_loss: 0.6931
# Iter 29, Fold 5, Epoch 4/100 | train_loss: 0.7050 | train_acc: 0.5223
#   PATCH-level: val_loss=0.6931, bal_acc=0.5749
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5300
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 5/100 | train_loss: 0.6913 | train_acc: 0.5374
#   PATCH-level: val_loss=0.7091, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5210
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 6/100 | train_loss: 0.6866 | train_acc: 0.5378
#   PATCH-level: val_loss=0.7226, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5147
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 7/100 | train_loss: 0.6863 | train_acc: 0.5403
#   PATCH-level: val_loss=0.7002, bal_acc=0.5353
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5103
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 8/100 | train_loss: 0.6828 | train_acc: 0.5495
#   PATCH-level: val_loss=0.7287, bal_acc=0.5294
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5072
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000299
# Iter 29, Fold 5, Epoch 9/100 | train_loss: 0.6911 | train_acc: 0.5315
#   PATCH-level: val_loss=0.6670, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5050
#   Best model: epoch 4, BA=0.6000, loss=0.6931
#   Best EMA smoothed: 0.5300 (epoch 4)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000299
#
#  BEST MODEL at epoch 10 (reason: better_slide_ba)
#    slide_BA: 0.6500 | val_loss: 0.6745
# Iter 29, Fold 5, Epoch 10/100 | train_loss: 0.6697 | train_acc: 0.5621
#   PATCH-level: val_loss=0.6745, bal_acc=0.5456
#   SLIDE-level: BA=0.6500 | EMA smoothed=0.5485
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5485 (epoch 10)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000298
# Iter 29, Fold 5, Epoch 11/100 | train_loss: 0.6512 | train_acc: 0.5861
#   PATCH-level: val_loss=0.6465, bal_acc=0.5821
#   SLIDE-level: BA=0.5500 | EMA smoothed=0.5490
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5485 (epoch 10)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000297
# Iter 29, Fold 5, Epoch 12/100 | train_loss: 0.6358 | train_acc: 0.6079
#   PATCH-level: val_loss=0.6234, bal_acc=0.6678
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5643
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5643 (epoch 12)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000296
# Iter 29, Fold 5, Epoch 13/100 | train_loss: 0.5966 | train_acc: 0.6444
#   PATCH-level: val_loss=0.6070, bal_acc=0.6842
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5750
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5750 (epoch 13)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000295
# Iter 29, Fold 5, Epoch 14/100 | train_loss: 0.5700 | train_acc: 0.6411
#   PATCH-level: val_loss=0.8146, bal_acc=0.6621
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5825
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5750 (epoch 13)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000293
# Iter 29, Fold 5, Epoch 15/100 | train_loss: 0.5511 | train_acc: 0.6755
#   PATCH-level: val_loss=0.7672, bal_acc=0.6713
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5877
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5877 (epoch 15)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000292
# Iter 29, Fold 5, Epoch 16/100 | train_loss: 0.5527 | train_acc: 0.6709
#   PATCH-level: val_loss=0.5756, bal_acc=0.6755
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5914
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5877 (epoch 15)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000290
# Iter 29, Fold 5, Epoch 17/100 | train_loss: 0.5405 | train_acc: 0.6973
#   PATCH-level: val_loss=0.5970, bal_acc=0.7132
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.5940
#   Best model: epoch 10, BA=0.6500, loss=0.6745
#   Best EMA smoothed: 0.5877 (epoch 15)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000288
#
#  BEST MODEL at epoch 18 (reason: better_slide_ba)
#    slide_BA: 0.8000 | val_loss: 0.5042
# Iter 29, Fold 5, Epoch 18/100 | train_loss: 0.4955 | train_acc: 0.7049
#   PATCH-level: val_loss=0.5042, bal_acc=0.7322
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.6558
#   Best model: epoch 18, BA=0.8000, loss=0.5042
#   Best EMA smoothed: 0.6558 (epoch 18)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000286
#
#  BEST MODEL at epoch 19 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8000 | val_loss: 0.4793
# Iter 29, Fold 5, Epoch 19/100 | train_loss: 0.4946 | train_acc: 0.7170
#   PATCH-level: val_loss=0.4793, bal_acc=0.7557
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.6991
#   Best model: epoch 19, BA=0.8000, loss=0.4793
#   Best EMA smoothed: 0.6991 (epoch 19)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000284
# Iter 29, Fold 5, Epoch 20/100 | train_loss: 0.5278 | train_acc: 0.6818
#   PATCH-level: val_loss=0.5781, bal_acc=0.7254
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.6693
#   Best model: epoch 19, BA=0.8000, loss=0.4793
#   Best EMA smoothed: 0.6991 (epoch 19)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000282
# Iter 29, Fold 5, Epoch 21/100 | train_loss: 0.4694 | train_acc: 0.7221
#   PATCH-level: val_loss=0.7964, bal_acc=0.6650
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.6485
#   Best model: epoch 19, BA=0.8000, loss=0.4793
#   Best EMA smoothed: 0.6991 (epoch 19)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000280
# Iter 29, Fold 5, Epoch 22/100 | train_loss: 0.4691 | train_acc: 0.7229
#   PATCH-level: val_loss=0.5143, bal_acc=0.7588
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.6940
#   Best model: epoch 19, BA=0.8000, loss=0.4793
#   Best EMA smoothed: 0.6991 (epoch 19)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000277
# Iter 29, Fold 5, Epoch 23/100 | train_loss: 0.4306 | train_acc: 0.7506
#   PATCH-level: val_loss=0.5312, bal_acc=0.7483
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.6958
#   Best model: epoch 19, BA=0.8000, loss=0.4793
#   Best EMA smoothed: 0.6991 (epoch 19)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000274
#
#  BEST MODEL at epoch 24 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8000 | val_loss: 0.4683
# Iter 29, Fold 5, Epoch 24/100 | train_loss: 0.4324 | train_acc: 0.7393
#   PATCH-level: val_loss=0.4683, bal_acc=0.7576
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7270
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7270 (epoch 24)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000271
# Iter 29, Fold 5, Epoch 25/100 | train_loss: 0.4551 | train_acc: 0.7628
#   PATCH-level: val_loss=0.5083, bal_acc=0.7686
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7489
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000268
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=23)
# Iter 29, Fold 5, Epoch 26/100 | train_loss: 0.4493 | train_acc: 0.7456
#   PATCH-level: val_loss=0.4250, bal_acc=0.7797
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7568
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000265
# Iter 29, Fold 5, Epoch 27/100 | train_loss: 0.4184 | train_acc: 0.7880
#   PATCH-level: val_loss=0.5975, bal_acc=0.7028
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.7097
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000262
# Iter 29, Fold 5, Epoch 28/100 | train_loss: 0.4127 | train_acc: 0.7464
#   PATCH-level: val_loss=0.6034, bal_acc=0.7221
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7068
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000259
# Iter 29, Fold 5, Epoch 29/100 | train_loss: 0.4005 | train_acc: 0.7376
#   PATCH-level: val_loss=0.5338, bal_acc=0.7436
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7048
#   Best model: epoch 24, BA=0.8000, loss=0.4683
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000255
#
#  BEST MODEL at epoch 30 (reason: better_slide_ba)
#    slide_BA: 0.8750 | val_loss: 0.4112
# Iter 29, Fold 5, Epoch 30/100 | train_loss: 0.4111 | train_acc: 0.7477
#   PATCH-level: val_loss=0.4112, bal_acc=0.7778
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.7558
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7489 (epoch 25)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000252
# Iter 29, Fold 5, Epoch 31/100 | train_loss: 0.4093 | train_acc: 0.7275
#   PATCH-level: val_loss=0.4260, bal_acc=0.8017
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7616
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7616 (epoch 31)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000248
# Iter 29, Fold 5, Epoch 32/100 | train_loss: 0.3658 | train_acc: 0.7695
#   PATCH-level: val_loss=0.3929, bal_acc=0.8157
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7656
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7616 (epoch 31)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000244
# Iter 29, Fold 5, Epoch 33/100 | train_loss: 0.4266 | train_acc: 0.7636
#   PATCH-level: val_loss=0.4601, bal_acc=0.7756
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7759
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000240
# Iter 29, Fold 5, Epoch 34/100 | train_loss: 0.3725 | train_acc: 0.7510
#   PATCH-level: val_loss=0.4815, bal_acc=0.7965
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7531
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000236
# Iter 29, Fold 5, Epoch 35/100 | train_loss: 0.3743 | train_acc: 0.8035
#   PATCH-level: val_loss=0.4279, bal_acc=0.8119
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7597
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000232
# Iter 29, Fold 5, Epoch 36/100 | train_loss: 0.3665 | train_acc: 0.7788
#   PATCH-level: val_loss=0.6481, bal_acc=0.7300
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7418
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000228
# Iter 29, Fold 5, Epoch 37/100 | train_loss: 0.3799 | train_acc: 0.7620
#   PATCH-level: val_loss=0.4991, bal_acc=0.7791
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7293
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000224
# Iter 29, Fold 5, Epoch 38/100 | train_loss: 0.3609 | train_acc: 0.7968
#   PATCH-level: val_loss=0.8098, bal_acc=0.6838
#   SLIDE-level: BA=0.6000 | EMA smoothed=0.6905
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000219
# Iter 29, Fold 5, Epoch 39/100 | train_loss: 0.3806 | train_acc: 0.7825
#   PATCH-level: val_loss=0.3639, bal_acc=0.8276
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7158
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000215
# Iter 29, Fold 5, Epoch 40/100 | train_loss: 0.3666 | train_acc: 0.7926
#   PATCH-level: val_loss=0.5043, bal_acc=0.7669
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7111
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000211
# Iter 29, Fold 5, Epoch 41/100 | train_loss: 0.3529 | train_acc: 0.7561
#   PATCH-level: val_loss=0.3995, bal_acc=0.8060
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7303
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000206
# Iter 29, Fold 5, Epoch 42/100 | train_loss: 0.3823 | train_acc: 0.7552
#   PATCH-level: val_loss=0.4255, bal_acc=0.8095
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7437
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000201
# Iter 29, Fold 5, Epoch 43/100 | train_loss: 0.3660 | train_acc: 0.7393
#   PATCH-level: val_loss=0.3824, bal_acc=0.8142
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7531
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000197
# Iter 29, Fold 5, Epoch 44/100 | train_loss: 0.3566 | train_acc: 0.8312
#   PATCH-level: val_loss=0.3425, bal_acc=0.8247
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7597
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000192
# Iter 29, Fold 5, Epoch 45/100 | train_loss: 0.3480 | train_acc: 0.7758
#   PATCH-level: val_loss=0.4868, bal_acc=0.7806
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7418
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000187
# Iter 29, Fold 5, Epoch 46/100 | train_loss: 0.3152 | train_acc: 0.7653
#   PATCH-level: val_loss=0.3662, bal_acc=0.8329
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7517
#   Best model: epoch 30, BA=0.8750, loss=0.4112
#   Best EMA smoothed: 0.7759 (epoch 33)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000182
#
#  BEST MODEL at epoch 47 (reason: better_slide_ba)
#    slide_BA: 0.9000 | val_loss: 0.4001
# Iter 29, Fold 5, Epoch 47/100 | train_loss: 0.3401 | train_acc: 0.7729
#   PATCH-level: val_loss=0.4001, bal_acc=0.8269
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.7962
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.7962 (epoch 47)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000178
# Iter 29, Fold 5, Epoch 48/100 | train_loss: 0.2814 | train_acc: 0.8350
#   PATCH-level: val_loss=0.3653, bal_acc=0.8319
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7898
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.7962 (epoch 47)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000173
# Iter 29, Fold 5, Epoch 49/100 | train_loss: 0.3039 | train_acc: 0.7666
#   PATCH-level: val_loss=0.3601, bal_acc=0.8468
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7854
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.7962 (epoch 47)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000168
# Iter 29, Fold 5, Epoch 50/100 | train_loss: 0.3225 | train_acc: 0.8165
#   PATCH-level: val_loss=0.3925, bal_acc=0.8281
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7823
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.7962 (epoch 47)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000163
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=46)
# Iter 29, Fold 5, Epoch 51/100 | train_loss: 0.3140 | train_acc: 0.8325
#   PATCH-level: val_loss=0.4641, bal_acc=0.7944
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7876
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.7962 (epoch 47)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000158
# Iter 29, Fold 5, Epoch 52/100 | train_loss: 0.3382 | train_acc: 0.7632
#   PATCH-level: val_loss=0.4406, bal_acc=0.7989
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.8213
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8213 (epoch 52)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000153
# Iter 29, Fold 5, Epoch 53/100 | train_loss: 0.2911 | train_acc: 0.8459
#   PATCH-level: val_loss=0.3507, bal_acc=0.8363
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8374
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000148
# Iter 29, Fold 5, Epoch 54/100 | train_loss: 0.3027 | train_acc: 0.7935
#   PATCH-level: val_loss=0.3349, bal_acc=0.8601
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8187
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000143
# Iter 29, Fold 5, Epoch 55/100 | train_loss: 0.2850 | train_acc: 0.8212
#   PATCH-level: val_loss=0.3963, bal_acc=0.8170
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8056
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000138
# Iter 29, Fold 5, Epoch 56/100 | train_loss: 0.2924 | train_acc: 0.7993
#   PATCH-level: val_loss=0.4735, bal_acc=0.7762
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8039
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000133
# Iter 29, Fold 5, Epoch 57/100 | train_loss: 0.2676 | train_acc: 0.8027
#   PATCH-level: val_loss=0.3506, bal_acc=0.8533
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7952
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000128
# Iter 29, Fold 5, Epoch 58/100 | train_loss: 0.3303 | train_acc: 0.7935
#   PATCH-level: val_loss=0.3369, bal_acc=0.8496
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7892
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000123
# Iter 29, Fold 5, Epoch 59/100 | train_loss: 0.3352 | train_acc: 0.8006
#   PATCH-level: val_loss=0.3542, bal_acc=0.8352
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7849
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000119
# Iter 29, Fold 5, Epoch 60/100 | train_loss: 0.2964 | train_acc: 0.8157
#   PATCH-level: val_loss=0.3479, bal_acc=0.8423
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7819
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000114
# Iter 29, Fold 5, Epoch 61/100 | train_loss: 0.2625 | train_acc: 0.8090
#   PATCH-level: val_loss=0.3530, bal_acc=0.8537
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8099
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000109
# Iter 29, Fold 5, Epoch 62/100 | train_loss: 0.2845 | train_acc: 0.7611
#   PATCH-level: val_loss=0.3315, bal_acc=0.8607
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7994
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000104
# Iter 29, Fold 5, Epoch 63/100 | train_loss: 0.2804 | train_acc: 0.8329
#   PATCH-level: val_loss=0.3302, bal_acc=0.8554
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8221
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000100
# Iter 29, Fold 5, Epoch 64/100 | train_loss: 0.3037 | train_acc: 0.7552
#   PATCH-level: val_loss=0.3249, bal_acc=0.8572
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8080
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000095
# Iter 29, Fold 5, Epoch 65/100 | train_loss: 0.2625 | train_acc: 0.7939
#   PATCH-level: val_loss=0.3410, bal_acc=0.8466
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7981
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000090
# Iter 29, Fold 5, Epoch 66/100 | train_loss: 0.3137 | train_acc: 0.7662
#   PATCH-level: val_loss=0.3164, bal_acc=0.8711
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8211
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000086
# Iter 29, Fold 5, Epoch 67/100 | train_loss: 0.2885 | train_acc: 0.8417
#   PATCH-level: val_loss=0.3671, bal_acc=0.8458
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8073
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000082
# Iter 29, Fold 5, Epoch 68/100 | train_loss: 0.2721 | train_acc: 0.8707
#   PATCH-level: val_loss=0.3425, bal_acc=0.8391
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7976
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 15/20 (remaining: 5)
#   LR: 0.000077
# Iter 29, Fold 5, Epoch 69/100 | train_loss: 0.2971 | train_acc: 0.8098
#   PATCH-level: val_loss=0.3409, bal_acc=0.8586
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8208
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 16/20 (remaining: 4)
#   LR: 0.000073
# Iter 29, Fold 5, Epoch 70/100 | train_loss: 0.2684 | train_acc: 0.8317
#   PATCH-level: val_loss=0.3419, bal_acc=0.8460
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8071
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 17/20 (remaining: 3)
#   LR: 0.000069
# Iter 29, Fold 5, Epoch 71/100 | train_loss: 0.2628 | train_acc: 0.8321
#   PATCH-level: val_loss=0.3548, bal_acc=0.8586
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8275
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 18/20 (remaining: 2)
#   LR: 0.000065
# Iter 29, Fold 5, Epoch 72/100 | train_loss: 0.2627 | train_acc: 0.8207
#   PATCH-level: val_loss=0.3627, bal_acc=0.8500
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8417
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8374 (epoch 53)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000061
# Iter 29, Fold 5, Epoch 73/100 | train_loss: 0.2403 | train_acc: 0.8283
#   PATCH-level: val_loss=0.3543, bal_acc=0.8580
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8517
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000057
# Iter 29, Fold 5, Epoch 74/100 | train_loss: 0.3170 | train_acc: 0.8048
#   PATCH-level: val_loss=0.3356, bal_acc=0.8506
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8587
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000053
# Iter 29, Fold 5, Epoch 75/100 | train_loss: 0.2670 | train_acc: 0.7909
#   PATCH-level: val_loss=0.3766, bal_acc=0.8328
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8336
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000049
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=46)
# Iter 29, Fold 5, Epoch 76/100 | train_loss: 0.2758 | train_acc: 0.8077
#   PATCH-level: val_loss=0.3298, bal_acc=0.8554
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8160
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000046
# Iter 29, Fold 5, Epoch 77/100 | train_loss: 0.2898 | train_acc: 0.7993
#   PATCH-level: val_loss=0.3329, bal_acc=0.8605
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8037
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000042
# Iter 29, Fold 5, Epoch 78/100 | train_loss: 0.2648 | train_acc: 0.8673
#   PATCH-level: val_loss=0.3440, bal_acc=0.8615
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.7951
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000039
# Iter 29, Fold 5, Epoch 79/100 | train_loss: 0.2955 | train_acc: 0.7880
#   PATCH-level: val_loss=0.3372, bal_acc=0.8629
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8191
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000036
# Iter 29, Fold 5, Epoch 80/100 | train_loss: 0.2328 | train_acc: 0.8711
#   PATCH-level: val_loss=0.3486, bal_acc=0.8517
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8058
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000033
# Iter 29, Fold 5, Epoch 81/100 | train_loss: 0.2650 | train_acc: 0.8010
#   PATCH-level: val_loss=0.3532, bal_acc=0.8660
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8266
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000030
# Iter 29, Fold 5, Epoch 82/100 | train_loss: 0.2573 | train_acc: 0.8615
#   PATCH-level: val_loss=0.3396, bal_acc=0.8572
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8111
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000027
# Iter 29, Fold 5, Epoch 83/100 | train_loss: 0.2513 | train_acc: 0.8031
#   PATCH-level: val_loss=0.3586, bal_acc=0.8462
#   SLIDE-level: BA=0.7750 | EMA smoothed=0.8003
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000024
# Iter 29, Fold 5, Epoch 84/100 | train_loss: 0.2354 | train_acc: 0.8694
#   PATCH-level: val_loss=0.3471, bal_acc=0.8646
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8227
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000021
# Iter 29, Fold 5, Epoch 85/100 | train_loss: 0.2960 | train_acc: 0.7788
#   PATCH-level: val_loss=0.3396, bal_acc=0.8601
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8384
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000019
# Iter 29, Fold 5, Epoch 86/100 | train_loss: 0.2778 | train_acc: 0.7955
#   PATCH-level: val_loss=0.3432, bal_acc=0.8647
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8494
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000017
# Iter 29, Fold 5, Epoch 87/100 | train_loss: 0.2604 | train_acc: 0.7872
#   PATCH-level: val_loss=0.3315, bal_acc=0.8635
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8571
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8517 (epoch 73)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000015
# Iter 29, Fold 5, Epoch 88/100 | train_loss: 0.2821 | train_acc: 0.8241
#   PATCH-level: val_loss=0.3321, bal_acc=0.8619
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8624
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8624 (epoch 88)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000013
# Iter 29, Fold 5, Epoch 89/100 | train_loss: 0.2764 | train_acc: 0.8094
#   PATCH-level: val_loss=0.3365, bal_acc=0.8601
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8662
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8624 (epoch 88)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000011
# Iter 29, Fold 5, Epoch 90/100 | train_loss: 0.2400 | train_acc: 0.8132
#   PATCH-level: val_loss=0.3370, bal_acc=0.8568
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8688
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8624 (epoch 88)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000009
# Iter 29, Fold 5, Epoch 91/100 | train_loss: 0.2451 | train_acc: 0.7901
#   PATCH-level: val_loss=0.3455, bal_acc=0.8627
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8707
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8624 (epoch 88)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000008
# Iter 29, Fold 5, Epoch 92/100 | train_loss: 0.2623 | train_acc: 0.8132
#   PATCH-level: val_loss=0.3394, bal_acc=0.8574
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8720
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8624 (epoch 88)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000006
# Iter 29, Fold 5, Epoch 93/100 | train_loss: 0.2736 | train_acc: 0.8501
#   PATCH-level: val_loss=0.3444, bal_acc=0.8654
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8729
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000005
# Iter 29, Fold 5, Epoch 94/100 | train_loss: 0.2624 | train_acc: 0.7817
#   PATCH-level: val_loss=0.3449, bal_acc=0.8660
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8735
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000004
# Iter 29, Fold 5, Epoch 95/100 | train_loss: 0.2403 | train_acc: 0.8493
#   PATCH-level: val_loss=0.3432, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8740
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000003
# Iter 29, Fold 5, Epoch 96/100 | train_loss: 0.2611 | train_acc: 0.7628
#   PATCH-level: val_loss=0.3434, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8743
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000002
# Iter 29, Fold 5, Epoch 97/100 | train_loss: 0.2556 | train_acc: 0.8610
#   PATCH-level: val_loss=0.3439, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8745
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000002
# Iter 29, Fold 5, Epoch 98/100 | train_loss: 0.2811 | train_acc: 0.7972
#   PATCH-level: val_loss=0.3433, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8746
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000001
# Iter 29, Fold 5, Epoch 99/100 | train_loss: 0.2637 | train_acc: 0.8296
#   PATCH-level: val_loss=0.3433, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8748
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000001
# Iter 29, Fold 5, Epoch 100/100 | train_loss: 0.2459 | train_acc: 0.8619
#   PATCH-level: val_loss=0.3435, bal_acc=0.8611
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8748
#   Best model: epoch 47, BA=0.9000, loss=0.4001
#   Best EMA smoothed: 0.8729 (epoch 93)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000001
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=46)
#
# RESTORED best model weights from epoch 47
#       1. slide_BA (maximize): 0.9000
#       2. val_loss (minimize): 0.4001
#     EMA smoothed at that epoch: 0.7962
#
# Saving FINAL checkpoint and history for Iter 29 Fold 5...
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=46)
#
# Iter 29 Fold 5 Summary (at best epoch 47):
#   SLIDE-LEVEL:
#     Balanced Acc: 0.9000
#     Val Loss:     0.4001
#     EMA smoothed: 0.7962
#     MCC: 0.8000
#     AUC: 0.9500
#   PATCH-LEVEL:
#     Balanced Acc: 0.8269
#     MCC: 0.6464
#   Training time: 2259.63s
#   Cleaned local checkpoint: iter_28_fold_3
#   Cleaned Drive checkpoint: iter_28_fold_3
#
# ======================================================================
# ITERATION 30/30 | base seed 911875363
# ======================================================================
#
# ✓ Valid splits found on first attempt
#   Effective seed: 911875363
# Fold 1/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2370']
#   Std:  ['0.0073']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 1...
#
# ======================================================================
# ITERATION 30/30 | FOLD 1/5
# Iteration Seed: 911875363
# Validation: ~10 slides, 681 patches
# Starting fold from scratch
# Model initialization seed: 1279365617
#   Model created with seed 1279365617: 5,325,058 params (5,325,058 trainable)
#
#  BEST MODEL at epoch 1 (reason: first_epoch)
#    slide_BA: 0.5000 | val_loss: 0.6753
# Iter 30, Fold 1, Epoch 1/100 | train_loss: 0.7084 | train_acc: 0.5146
#   PATCH-level: val_loss=0.6753, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000120
# Iter 30, Fold 1, Epoch 2/100 | train_loss: 0.7092 | train_acc: 0.5249
#   PATCH-level: val_loss=0.6891, bal_acc=0.5052
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000180
# Iter 30, Fold 1, Epoch 3/100 | train_loss: 0.6999 | train_acc: 0.4953
#   PATCH-level: val_loss=0.6757, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000240
# Iter 30, Fold 1, Epoch 4/100 | train_loss: 0.6914 | train_acc: 0.5406
#   PATCH-level: val_loss=0.6798, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000300
# Iter 30, Fold 1, Epoch 5/100 | train_loss: 0.6940 | train_acc: 0.5253
#   PATCH-level: val_loss=0.7035, bal_acc=0.5025
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000300
# Iter 30, Fold 1, Epoch 6/100 | train_loss: 0.6910 | train_acc: 0.5258
#   PATCH-level: val_loss=0.6788, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5000
#   Best model: epoch 1, BA=0.5000, loss=0.6753
#   Best EMA smoothed: 0.5000 (epoch 1)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000300
#
#  BEST MODEL at epoch 7 (reason: better_slide_ba)
#    slide_BA: 0.5417 | val_loss: 0.6827
# Iter 30, Fold 1, Epoch 7/100 | train_loss: 0.6893 | train_acc: 0.5469
#   PATCH-level: val_loss=0.6827, bal_acc=0.6645
#   SLIDE-level: BA=0.5417 | EMA smoothed=0.5125
#   Best model: epoch 7, BA=0.5417, loss=0.6827
#   Best EMA smoothed: 0.5125 (epoch 7)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
# Iter 30, Fold 1, Epoch 8/100 | train_loss: 0.6905 | train_acc: 0.5334
#   PATCH-level: val_loss=0.6679, bal_acc=0.5000
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5087
#   Best model: epoch 7, BA=0.5417, loss=0.6827
#   Best EMA smoothed: 0.5125 (epoch 7)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000299
#
#  BEST MODEL at epoch 9 (reason: better_slide_ba)
#    slide_BA: 0.6667 | val_loss: 0.6819
# Iter 30, Fold 1, Epoch 9/100 | train_loss: 0.6817 | train_acc: 0.5419
#   PATCH-level: val_loss=0.6819, bal_acc=0.6093
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.5561
#   Best model: epoch 9, BA=0.6667, loss=0.6819
#   Best EMA smoothed: 0.5561 (epoch 9)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
#
#  BEST MODEL at epoch 10 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.6667 | val_loss: 0.6589
# Iter 30, Fold 1, Epoch 10/100 | train_loss: 0.6688 | train_acc: 0.5900
#   PATCH-level: val_loss=0.6589, bal_acc=0.6131
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.5893
#   Best model: epoch 10, BA=0.6667, loss=0.6589
#   Best EMA smoothed: 0.5893 (epoch 10)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000298
#
#  BEST MODEL at epoch 11 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.6667 | val_loss: 0.6418
# Iter 30, Fold 1, Epoch 11/100 | train_loss: 0.6544 | train_acc: 0.5904
#   PATCH-level: val_loss=0.6418, bal_acc=0.6556
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.6125
#   Best model: epoch 11, BA=0.6667, loss=0.6418
#   Best EMA smoothed: 0.6125 (epoch 11)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000297
# Iter 30, Fold 1, Epoch 12/100 | train_loss: 0.6286 | train_acc: 0.6214
#   PATCH-level: val_loss=0.8302, bal_acc=0.5544
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5788
#   Best model: epoch 11, BA=0.6667, loss=0.6418
#   Best EMA smoothed: 0.6125 (epoch 11)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000296
# Iter 30, Fold 1, Epoch 13/100 | train_loss: 0.6331 | train_acc: 0.6133
#   PATCH-level: val_loss=0.9821, bal_acc=0.5675
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.5551
#   Best model: epoch 11, BA=0.6667, loss=0.6418
#   Best EMA smoothed: 0.6125 (epoch 11)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000295
#
#  BEST MODEL at epoch 14 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.6667 | val_loss: 0.6063
# Iter 30, Fold 1, Epoch 14/100 | train_loss: 0.6017 | train_acc: 0.6698
#   PATCH-level: val_loss=0.6063, bal_acc=0.7316
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.5886
#   Best model: epoch 14, BA=0.6667, loss=0.6063
#   Best EMA smoothed: 0.6125 (epoch 11)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000293
#
#  BEST MODEL at epoch 15 (reason: better_slide_ba)
#    slide_BA: 0.8333 | val_loss: 0.5319
# Iter 30, Fold 1, Epoch 15/100 | train_loss: 0.5805 | train_acc: 0.6738
#   PATCH-level: val_loss=0.5319, bal_acc=0.7439
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.6620
#   Best model: epoch 15, BA=0.8333, loss=0.5319
#   Best EMA smoothed: 0.6620 (epoch 15)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000292
# Iter 30, Fold 1, Epoch 16/100 | train_loss: 0.5600 | train_acc: 0.6990
#   PATCH-level: val_loss=0.5287, bal_acc=0.7633
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.6884
#   Best model: epoch 15, BA=0.8333, loss=0.5319
#   Best EMA smoothed: 0.6884 (epoch 16)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000290
# Iter 30, Fold 1, Epoch 17/100 | train_loss: 0.5537 | train_acc: 0.6927
#   PATCH-level: val_loss=0.5910, bal_acc=0.7259
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.6819
#   Best model: epoch 15, BA=0.8333, loss=0.5319
#   Best EMA smoothed: 0.6884 (epoch 16)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000288
#
#  BEST MODEL at epoch 18 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8333 | val_loss: 0.4920
# Iter 30, Fold 1, Epoch 18/100 | train_loss: 0.5852 | train_acc: 0.6572
#   PATCH-level: val_loss=0.4920, bal_acc=0.7923
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7273
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7273 (epoch 18)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000286
# Iter 30, Fold 1, Epoch 19/100 | train_loss: 0.5150 | train_acc: 0.6985
#   PATCH-level: val_loss=0.7306, bal_acc=0.6904
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.7091
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7273 (epoch 18)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000284
# Iter 30, Fold 1, Epoch 20/100 | train_loss: 0.5172 | train_acc: 0.7066
#   PATCH-level: val_loss=0.5809, bal_acc=0.7655
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.6964
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7273 (epoch 18)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000282
# Iter 30, Fold 1, Epoch 21/100 | train_loss: 0.5102 | train_acc: 0.7295
#   PATCH-level: val_loss=0.5095, bal_acc=0.8046
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7375
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000280
# Iter 30, Fold 1, Epoch 22/100 | train_loss: 0.4588 | train_acc: 0.7322
#   PATCH-level: val_loss=0.5467, bal_acc=0.7838
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7412
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000277
# Iter 30, Fold 1, Epoch 23/100 | train_loss: 0.4570 | train_acc: 0.7559
#   PATCH-level: val_loss=0.5872, bal_acc=0.8011
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7439
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000274
# Iter 30, Fold 1, Epoch 24/100 | train_loss: 0.4395 | train_acc: 0.7761
#   PATCH-level: val_loss=0.6529, bal_acc=0.8011
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7457
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000271
# Iter 30, Fold 1, Epoch 25/100 | train_loss: 0.4713 | train_acc: 0.7322
#   PATCH-level: val_loss=0.8094, bal_acc=0.7174
#   SLIDE-level: BA=0.5833 | EMA smoothed=0.6970
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000268
# Checkpoint saved: cv_iter_29_fold_0_checkpoint.pth (best_epoch=17)
# Iter 30, Fold 1, Epoch 26/100 | train_loss: 0.4440 | train_acc: 0.7425
#   PATCH-level: val_loss=0.5191, bal_acc=0.8109
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7379
#   Best model: epoch 18, BA=0.8333, loss=0.4920
#   Best EMA smoothed: 0.7375 (epoch 21)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000265
#
#  BEST MODEL at epoch 27 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8333 | val_loss: 0.4787
# Iter 30, Fold 1, Epoch 27/100 | train_loss: 0.4431 | train_acc: 0.7416
#   PATCH-level: val_loss=0.4787, bal_acc=0.8262
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7665
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7665 (epoch 27)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000262
# Iter 30, Fold 1, Epoch 28/100 | train_loss: 0.4517 | train_acc: 0.7281
#   PATCH-level: val_loss=0.5196, bal_acc=0.8099
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7616
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7665 (epoch 27)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000259
# Iter 30, Fold 1, Epoch 29/100 | train_loss: 0.4228 | train_acc: 0.7604
#   PATCH-level: val_loss=0.4924, bal_acc=0.8192
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7831
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000255
# Iter 30, Fold 1, Epoch 30/100 | train_loss: 0.4622 | train_acc: 0.7739
#   PATCH-level: val_loss=0.5348, bal_acc=0.8016
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7732
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000252
# Iter 30, Fold 1, Epoch 31/100 | train_loss: 0.4146 | train_acc: 0.7465
#   PATCH-level: val_loss=0.4951, bal_acc=0.8159
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.7662
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000248
# Iter 30, Fold 1, Epoch 32/100 | train_loss: 0.4026 | train_acc: 0.7645
#   PATCH-level: val_loss=0.5464, bal_acc=0.8225
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7864
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000244
# Iter 30, Fold 1, Epoch 33/100 | train_loss: 0.4285 | train_acc: 0.7326
#   PATCH-level: val_loss=0.6323, bal_acc=0.7655
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.7504
#   Best model: epoch 27, BA=0.8333, loss=0.4787
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000240
#
#  BEST MODEL at epoch 34 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8333 | val_loss: 0.4298
# Iter 30, Fold 1, Epoch 34/100 | train_loss: 0.4237 | train_acc: 0.7555
#   PATCH-level: val_loss=0.4298, bal_acc=0.8402
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7753
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000236
# Iter 30, Fold 1, Epoch 35/100 | train_loss: 0.4111 | train_acc: 0.7398
#   PATCH-level: val_loss=0.4327, bal_acc=0.8374
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7927
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000232
# Iter 30, Fold 1, Epoch 36/100 | train_loss: 0.4242 | train_acc: 0.7187
#   PATCH-level: val_loss=0.6653, bal_acc=0.7391
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.7549
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000228
# Iter 30, Fold 1, Epoch 37/100 | train_loss: 0.4004 | train_acc: 0.7519
#   PATCH-level: val_loss=1.0239, bal_acc=0.6753
#   SLIDE-level: BA=0.5833 | EMA smoothed=0.7034
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000224
# Iter 30, Fold 1, Epoch 38/100 | train_loss: 0.4142 | train_acc: 0.7663
#   PATCH-level: val_loss=0.5009, bal_acc=0.8301
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7424
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000219
# Iter 30, Fold 1, Epoch 39/100 | train_loss: 0.3899 | train_acc: 0.7815
#   PATCH-level: val_loss=0.4461, bal_acc=0.8420
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7697
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000215
# Iter 30, Fold 1, Epoch 40/100 | train_loss: 0.3969 | train_acc: 0.7649
#   PATCH-level: val_loss=0.4537, bal_acc=0.8530
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7888
#   Best model: epoch 34, BA=0.8333, loss=0.4298
#   Best EMA smoothed: 0.7831 (epoch 29)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000211
#
#  BEST MODEL at epoch 41 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8333 | val_loss: 0.4149
# Iter 30, Fold 1, Epoch 41/100 | train_loss: 0.3799 | train_acc: 0.7335
#   PATCH-level: val_loss=0.4149, bal_acc=0.8592
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.8021
#   Best model: epoch 41, BA=0.8333, loss=0.4149
#   Best EMA smoothed: 0.8021 (epoch 41)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000206
# Iter 30, Fold 1, Epoch 42/100 | train_loss: 0.3870 | train_acc: 0.7084
#   PATCH-level: val_loss=0.4623, bal_acc=0.8304
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.8115
#   Best model: epoch 41, BA=0.8333, loss=0.4149
#   Best EMA smoothed: 0.8021 (epoch 41)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000201
# Iter 30, Fold 1, Epoch 43/100 | train_loss: 0.3920 | train_acc: 0.7618
#   PATCH-level: val_loss=0.4297, bal_acc=0.8461
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.8181
#   Best model: epoch 41, BA=0.8333, loss=0.4149
#   Best EMA smoothed: 0.8181 (epoch 43)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000197
# Iter 30, Fold 1, Epoch 44/100 | train_loss: 0.3809 | train_acc: 0.7945
#   PATCH-level: val_loss=0.5080, bal_acc=0.8366
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.8226
#   Best model: epoch 41, BA=0.8333, loss=0.4149
#   Best EMA smoothed: 0.8181 (epoch 43)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000192
# Iter 30, Fold 1, Epoch 45/100 | train_loss: 0.3811 | train_acc: 0.7945
#   PATCH-level: val_loss=0.5424, bal_acc=0.8106
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.8258
#   Best model: epoch 41, BA=0.8333, loss=0.4149
#   Best EMA smoothed: 0.8181 (epoch 43)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000187
#
#  BEST MODEL at epoch 46 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8333 | val_loss: 0.4067
# ...
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000168
# Iter 30, Fold 5, Epoch 50/100 | train_loss: 0.3586 | train_acc: 0.7724
#   PATCH-level: val_loss=1.0127, bal_acc=0.6418
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7566
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 15/20 (remaining: 5)
#   LR: 0.000163
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=31)
# Iter 30, Fold 5, Epoch 51/100 | train_loss: 0.3254 | train_acc: 0.8142
#   PATCH-level: val_loss=0.7963, bal_acc=0.6796
#   SLIDE-level: BA=0.6750 | EMA smoothed=0.7321
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 16/20 (remaining: 4)
#   LR: 0.000158
# Iter 30, Fold 5, Epoch 52/100 | train_loss: 0.3410 | train_acc: 0.7814
#   PATCH-level: val_loss=0.6738, bal_acc=0.6944
#   SLIDE-level: BA=0.6750 | EMA smoothed=0.7150
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 17/20 (remaining: 3)
#   LR: 0.000153
# Iter 30, Fold 5, Epoch 53/100 | train_loss: 0.3139 | train_acc: 0.8052
#   PATCH-level: val_loss=0.8384, bal_acc=0.6739
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7405
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 18/20 (remaining: 2)
#   LR: 0.000148
# Iter 30, Fold 5, Epoch 54/100 | train_loss: 0.3344 | train_acc: 0.8045
#   PATCH-level: val_loss=0.6791, bal_acc=0.6837
#   SLIDE-level: BA=0.6750 | EMA smoothed=0.7208
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000143
# Iter 30, Fold 5, Epoch 55/100 | train_loss: 0.3514 | train_acc: 0.7783
#   PATCH-level: val_loss=0.6768, bal_acc=0.6928
#   SLIDE-level: BA=0.6750 | EMA smoothed=0.7071
#   Best model: epoch 32, BA=0.8000, loss=0.6987
#   Best EMA smoothed: 0.7847 (epoch 35)
#   Patience: 20/20 (remaining: 0)
#   LR: 0.000138
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=31)
#
#  EARLY STOPPING triggered at epoch 55
#    Best model: epoch 32
#    slide_BA=0.8000,    val_loss=0.6987
#    Best EMA smoothed: 0.7847 (epoch 35)
#
# RESTORED best model weights from epoch 32
#       1. slide_BA (maximize): 0.8000
#       2. val_loss (minimize): 0.6987
#     EMA smoothed at that epoch: 0.7555
#
# Saving FINAL checkpoint and history for Iter 30 Fold 5...
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=31)
#
# Iter 30 Fold 5 Summary (at best epoch 32):
#   SLIDE-LEVEL:
#     Balanced Acc: 0.8000
#     Val Loss:     0.6987
#     EMA smoothed: 0.7555
#     MCC: 0.6325
#     AUC: 0.9000
#   PATCH-LEVEL:
#     Balanced Acc: 0.7045
#     MCC: 0.4337
#   Training time: 1329.41s
#   Cleaned local checkpoint: iter_29_fold_3
#   Cleaned Drive checkpoint: iter_29_fold_3
#
# ======================================================================
# CROSS-VALIDATION COMPLETE
# ======================================================================
#
# Completed 30 iterations × 5 folds
# Total fold summaries: 150
#
# Next phase: Analysis
# ======================================================================
#
# ----------------------------------------------------------------------
# PHASE: ANALYSIS
# ----------------------------------------------------------------------
# Loaded 150 fold summaries | iterations=30
# CV results saved to: /content/checkpoints/standard/cv_results_standard.csv
# Backed up to Drive: /content/drive/MyDrive/colab/vit_fungi/checkpoints/standard/cv_results_standard.csv
# CV iteration distribution plot saved to: /content/drive/MyDrive/colab/vit_fungi/output/standard/cv_iteration_results_standard.png
# Determining optimal number of epochs...
#
# ======================================================================
# OPTIMAL EPOCHS CALCULATION (Hierarchically Correct)
# ======================================================================
# Input: 150 valid folds from 30 iterations
# Method: median
#
#   Selected method: Median of iteration means
#   Raw value: 59.20 epochs
#
# ✓ Train final model for 60 epochs
# ======================================================================
#
# Selected optimal_epochs: 60
#
# Loading training histories for 30 iterations × 5 folds...
#   Loaded: Iter 1 Fold 1 (94 epochs)
#   Loaded: Iter 1 Fold 2 (48 epochs)
#   Loaded: Iter 1 Fold 3 (81 epochs)
#   Loaded: Iter 1 Fold 4 (27 epochs)
#   Loaded: Iter 1 Fold 5 (100 epochs)
#   Loaded: Iter 2 Fold 1 (100 epochs)
#   Loaded: Iter 2 Fold 2 (100 epochs)
#   Loaded: Iter 2 Fold 3 (59 epochs)
#   Loaded: Iter 2 Fold 4 (55 epochs)
#   Loaded: Iter 2 Fold 5 (20 epochs)
#   Loaded: Iter 3 Fold 1 (93 epochs)
#   Loaded: Iter 3 Fold 2 (100 epochs)
#   Loaded: Iter 3 Fold 3 (100 epochs)
#   Loaded: Iter 3 Fold 4 (100 epochs)
#   Loaded: Iter 3 Fold 5 (85 epochs)
#   Loaded: Iter 4 Fold 1 (41 epochs)
#   Loaded: Iter 4 Fold 2 (49 epochs)
#   Loaded: Iter 4 Fold 3 (20 epochs)
#   Loaded: Iter 4 Fold 4 (67 epochs)
#   Loaded: Iter 4 Fold 5 (59 epochs)
#   Loaded: Iter 5 Fold 1 (100 epochs)
#   Loaded: Iter 5 Fold 2 (88 epochs)
#   Loaded: Iter 5 Fold 3 (75 epochs)
#   Loaded: Iter 5 Fold 4 (47 epochs)
#   Loaded: Iter 5 Fold 5 (99 epochs)
#   Loaded: Iter 6 Fold 1 (52 epochs)
#   Loaded: Iter 6 Fold 2 (43 epochs)
#   Loaded: Iter 6 Fold 3 (61 epochs)
#   Loaded: Iter 6 Fold 4 (79 epochs)
#   Loaded: Iter 6 Fold 5 (100 epochs)
#   Loaded: Iter 7 Fold 1 (39 epochs)
#   Loaded: Iter 7 Fold 2 (87 epochs)
#   Loaded: Iter 7 Fold 3 (29 epochs)
#   Loaded: Iter 7 Fold 4 (100 epochs)
#   Loaded: Iter 7 Fold 5 (74 epochs)
#   Loaded: Iter 8 Fold 1 (41 epochs)
#   Loaded: Iter 8 Fold 2 (20 epochs)
#   Loaded: Iter 8 Fold 3 (77 epochs)
#   Loaded: Iter 8 Fold 4 (86 epochs)
#   Loaded: Iter 8 Fold 5 (64 epochs)
#   Loaded: Iter 9 Fold 1 (43 epochs)
#   Loaded: Iter 9 Fold 2 (89 epochs)
#   Loaded: Iter 9 Fold 3 (39 epochs)
#   Loaded: Iter 9 Fold 4 (60 epochs)
#   Loaded: Iter 9 Fold 5 (73 epochs)
#   Loaded: Iter 10 Fold 1 (66 epochs)
#   Loaded: Iter 10 Fold 2 (86 epochs)
#   Loaded: Iter 10 Fold 3 (61 epochs)
#   Loaded: Iter 10 Fold 4 (91 epochs)
#   Loaded: Iter 10 Fold 5 (100 epochs)
#   Loaded: Iter 11 Fold 1 (91 epochs)
#   Loaded: Iter 11 Fold 2 (62 epochs)
#   Loaded: Iter 11 Fold 3 (57 epochs)
#   Loaded: Iter 11 Fold 4 (96 epochs)
#   Loaded: Iter 11 Fold 5 (81 epochs)
#   Loaded: Iter 12 Fold 1 (47 epochs)
#   Loaded: Iter 12 Fold 2 (51 epochs)
#   Loaded: Iter 12 Fold 3 (63 epochs)
#   Loaded: Iter 12 Fold 4 (88 epochs)
#   Loaded: Iter 12 Fold 5 (38 epochs)
#   Loaded: Iter 13 Fold 1 (87 epochs)
#   Loaded: Iter 13 Fold 2 (84 epochs)
#   Loaded: Iter 13 Fold 3 (49 epochs)
#   Loaded: Iter 13 Fold 4 (70 epochs)
#   Loaded: Iter 13 Fold 5 (100 epochs)
#   Loaded: Iter 14 Fold 1 (71 epochs)
#   Loaded: Iter 14 Fold 2 (100 epochs)
#   Loaded: Iter 14 Fold 3 (23 epochs)
#   Loaded: Iter 14 Fold 4 (100 epochs)
#   Loaded: Iter 14 Fold 5 (100 epochs)
#   Loaded: Iter 15 Fold 1 (98 epochs)
#   Loaded: Iter 15 Fold 2 (98 epochs)
#   Loaded: Iter 15 Fold 3 (81 epochs)
#   Loaded: Iter 15 Fold 4 (80 epochs)
#   Loaded: Iter 15 Fold 5 (100 epochs)
#   Loaded: Iter 16 Fold 1 (100 epochs)
#   Loaded: Iter 16 Fold 2 (54 epochs)
#   Loaded: Iter 16 Fold 3 (100 epochs)
#   Loaded: Iter 16 Fold 4 (100 epochs)
#   Loaded: Iter 16 Fold 5 (55 epochs)
#   Loaded: Iter 17 Fold 1 (20 epochs)
#   Loaded: Iter 17 Fold 2 (74 epochs)
#   Loaded: Iter 17 Fold 3 (91 epochs)
#   Loaded: Iter 17 Fold 4 (100 epochs)
#   Loaded: Iter 17 Fold 5 (100 epochs)
#   Loaded: Iter 18 Fold 1 (90 epochs)
#   Loaded: Iter 18 Fold 2 (43 epochs)
#   Loaded: Iter 18 Fold 3 (87 epochs)
#   Loaded: Iter 18 Fold 4 (100 epochs)
#   Loaded: Iter 18 Fold 5 (25 epochs)
#   Loaded: Iter 19 Fold 1 (89 epochs)
#   Loaded: Iter 19 Fold 2 (69 epochs)
#   Loaded: Iter 19 Fold 3 (68 epochs)
#   Loaded: Iter 19 Fold 4 (89 epochs)
#   Loaded: Iter 19 Fold 5 (28 epochs)
#   Loaded: Iter 20 Fold 1 (62 epochs)
#   Loaded: Iter 20 Fold 2 (83 epochs)
#   Loaded: Iter 20 Fold 3 (63 epochs)
#   Loaded: Iter 20 Fold 4 (100 epochs)
#   Loaded: Iter 20 Fold 5 (100 epochs)
#   Loaded: Iter 21 Fold 1 (100 epochs)
#   Loaded: Iter 21 Fold 2 (73 epochs)
#   Loaded: Iter 21 Fold 3 (97 epochs)
#   Loaded: Iter 21 Fold 4 (57 epochs)
#   Loaded: Iter 21 Fold 5 (87 epochs)
#   Loaded: Iter 22 Fold 1 (82 epochs)
#   Loaded: Iter 22 Fold 2 (55 epochs)
#   Loaded: Iter 22 Fold 3 (100 epochs)
#   Loaded: Iter 22 Fold 4 (100 epochs)
#   Loaded: Iter 22 Fold 5 (63 epochs)
#   Loaded: Iter 23 Fold 1 (52 epochs)
#   Loaded: Iter 23 Fold 2 (94 epochs)
#   Loaded: Iter 23 Fold 3 (91 epochs)
#   Loaded: Iter 23 Fold 4 (53 epochs)
#   Loaded: Iter 23 Fold 5 (80 epochs)
#   Loaded: Iter 24 Fold 1 (67 epochs)
#   Loaded: Iter 24 Fold 2 (51 epochs)
#   Loaded: Iter 24 Fold 3 (47 epochs)
#   Loaded: Iter 24 Fold 4 (56 epochs)
#   Loaded: Iter 24 Fold 5 (87 epochs)
#   Loaded: Iter 25 Fold 1 (20 epochs)
#   Loaded: Iter 25 Fold 2 (35 epochs)
#   Loaded: Iter 25 Fold 3 (93 epochs)
#   Loaded: Iter 25 Fold 4 (56 epochs)
#   Loaded: Iter 25 Fold 5 (100 epochs)
#   Loaded: Iter 26 Fold 1 (20 epochs)
#   Loaded: Iter 26 Fold 2 (87 epochs)
#   Loaded: Iter 26 Fold 3 (100 epochs)
#   Loaded: Iter 26 Fold 4 (63 epochs)
#   Loaded: Iter 26 Fold 5 (100 epochs)
#   Loaded: Iter 27 Fold 1 (94 epochs)
#   Loaded: Iter 27 Fold 2 (45 epochs)
#   Loaded: Iter 27 Fold 3 (61 epochs)
#   Loaded: Iter 27 Fold 4 (56 epochs)
#   Loaded: Iter 27 Fold 5 (100 epochs)
#   Loaded: Iter 28 Fold 1 (79 epochs)
#   Loaded: Iter 28 Fold 2 (43 epochs)
#   Loaded: Iter 28 Fold 3 (100 epochs)
#   Loaded: Iter 28 Fold 4 (52 epochs)
#   Loaded: Iter 28 Fold 5 (73 epochs)
#   Loaded: Iter 29 Fold 1 (76 epochs)
#   Loaded: Iter 29 Fold 2 (100 epochs)
#   Loaded: Iter 29 Fold 3 (100 epochs)
#   Loaded: Iter 29 Fold 4 (51 epochs)
#   Loaded: Iter 29 Fold 5 (100 epochs)
#   Loaded: Iter 30 Fold 1 (66 epochs)
#   Loaded: Iter 30 Fold 2 (73 epochs)
#   Loaded: Iter 30 Fold 3 (79 epochs)
#   Loaded: Iter 30 Fold 4 (100 epochs)
#   Loaded: Iter 30 Fold 5 (55 epochs)
#
# Successfully loaded 150 training histories
#
# Analyzing 150 training curves...
#   Population learning curves saved: learning_curves_population_standard.png
#   Generalization gap analysis saved: generalization_gap_standard.png
#   Overfitting indicators saved: overfitting_indicators_standard.png
#   Early stopping distribution saved: early_stopping_dist_standard.png
#   Best/worst examples saved: best_worst_folds_standard.png
#   Patch vs slide comparison saved: patch_vs_slide_comparison_standard.png
#   Slide metric stability analysis saved: slide_metric_stability_standard.png
#   Statistical report saved: training_dynamics_statistics_standard.txt
#
#   Cleaning up fold histories after analysis...
#
#  Cleaned up 150 fold history file(s) after evaluation
#
#  Cleaned up 2 CV checkpoint(s) after analysis completion
# ----------------------------------------------------------------------
# ANALYSIS COMPLETE
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# PHASE: FINAL TRAINING
# ----------------------------------------------------------------------
# Training final model for 60 epochs
# Calculating normalization statistics on full training set...
# Final mean: [0.23691008985042572]
# Final std: [0.007409718818962574]
# Using uniform class weights (gamma=0, recommended with MixUp)
# MixUp enabled: alpha=0.2, prob=0.5
#
# ======================================================================
# TRAINING FINAL MODEL FOR 60 EPOCHS
# Using Base Seed: 42
# ======================================================================
# Starting final training from scratch
#   Model created with seed 42: 5,325,058 params (5,325,058 trainable)
# Epoch 1/60 | Loss: 0.7115 | Acc: 0.5120 | LR: 0.000120
# Epoch 2/60 | Loss: 0.6919 | Acc: 0.5402 | LR: 0.000180
# Epoch 3/60 | Loss: 0.6914 | Acc: 0.5388 | LR: 0.000240
# Epoch 4/60 | Loss: 0.6859 | Acc: 0.5509 | LR: 0.000300
# Epoch 5/60 | Loss: 0.6871 | Acc: 0.5498 | LR: 0.000300
# Epoch 6/60 | Loss: 0.6824 | Acc: 0.5636 | LR: 0.000300
# Epoch 7/60 | Loss: 0.6848 | Acc: 0.5674 | LR: 0.000299
# Epoch 8/60 | Loss: 0.6801 | Acc: 0.5457 | LR: 0.000298
# Epoch 9/60 | Loss: 0.6837 | Acc: 0.5491 | LR: 0.000296
# Epoch 10/60 | Loss: 0.6654 | Acc: 0.5838 | LR: 0.000294
# Epoch 11/60 | Loss: 0.6519 | Acc: 0.5893 | LR: 0.000291
# Epoch 12/60 | Loss: 0.6180 | Acc: 0.6254 | LR: 0.000288
# Epoch 13/60 | Loss: 0.5798 | Acc: 0.6601 | LR: 0.000285
# Epoch 14/60 | Loss: 0.5894 | Acc: 0.6423 | LR: 0.000281
# Epoch 15/60 | Loss: 0.5030 | Acc: 0.7124 | LR: 0.000276
# Epoch 16/60 | Loss: 0.4827 | Acc: 0.7385 | LR: 0.000271
# Epoch 17/60 | Loss: 0.4863 | Acc: 0.6842 | LR: 0.000266
# Epoch 18/60 | Loss: 0.4336 | Acc: 0.7687 | LR: 0.000261
# Epoch 19/60 | Loss: 0.4313 | Acc: 0.7588 | LR: 0.000255
# Epoch 20/60 | Loss: 0.4434 | Acc: 0.7192 | LR: 0.000248
# Epoch 21/60 | Loss: 0.4363 | Acc: 0.7474 | LR: 0.000242
# Epoch 22/60 | Loss: 0.3963 | Acc: 0.7402 | LR: 0.000235
# Epoch 23/60 | Loss: 0.4082 | Acc: 0.7364 | LR: 0.000228
# Epoch 24/60 | Loss: 0.3991 | Acc: 0.7763 | LR: 0.000220
# Epoch 25/60 | Loss: 0.4072 | Acc: 0.7777 | LR: 0.000213
# Checkpoint saved: final_model_checkpoint.pth
#   Backed up to Drive: final_model_checkpoint.pth
# Epoch 26/60 | Loss: 0.4037 | Acc: 0.7543 | LR: 0.000205
# Epoch 27/60 | Loss: 0.3938 | Acc: 0.7931 | LR: 0.000197
# Epoch 28/60 | Loss: 0.3927 | Acc: 0.7753 | LR: 0.000189
# Epoch 29/60 | Loss: 0.3835 | Acc: 0.7990 | LR: 0.000180
# Epoch 30/60 | Loss: 0.3875 | Acc: 0.7801 | LR: 0.000172
# Epoch 31/60 | Loss: 0.3577 | Acc: 0.7691 | LR: 0.000163
# Epoch 32/60 | Loss: 0.3359 | Acc: 0.7842 | LR: 0.000155
# Epoch 33/60 | Loss: 0.3699 | Acc: 0.7646 | LR: 0.000146
# Epoch 34/60 | Loss: 0.3633 | Acc: 0.7667 | LR: 0.000138
# Epoch 35/60 | Loss: 0.3577 | Acc: 0.7838 | LR: 0.000129
# Epoch 36/60 | Loss: 0.3915 | Acc: 0.7649 | LR: 0.000121
# Epoch 37/60 | Loss: 0.3424 | Acc: 0.7976 | LR: 0.000112
# Epoch 38/60 | Loss: 0.3857 | Acc: 0.7780 | LR: 0.000104
# Epoch 39/60 | Loss: 0.3022 | Acc: 0.7845 | LR: 0.000096
# Epoch 40/60 | Loss: 0.3528 | Acc: 0.7931 | LR: 0.000088
# Epoch 41/60 | Loss: 0.3343 | Acc: 0.8052 | LR: 0.000081
# Epoch 42/60 | Loss: 0.3185 | Acc: 0.7924 | LR: 0.000073
# Epoch 43/60 | Loss: 0.3159 | Acc: 0.8186 | LR: 0.000066
# Epoch 44/60 | Loss: 0.3157 | Acc: 0.7773 | LR: 0.000059
# Epoch 45/60 | Loss: 0.3085 | Acc: 0.8096 | LR: 0.000053
# Epoch 46/60 | Loss: 0.3408 | Acc: 0.7928 | LR: 0.000046
# Epoch 47/60 | Loss: 0.3093 | Acc: 0.8247 | LR: 0.000040
# Epoch 48/60 | Loss: 0.3005 | Acc: 0.7856 | LR: 0.000035
# Epoch 49/60 | Loss: 0.2874 | Acc: 0.8405 | LR: 0.000030
# Epoch 50/60 | Loss: 0.3317 | Acc: 0.7959 | LR: 0.000025
# Checkpoint saved: final_model_checkpoint.pth
#   Backed up to Drive: final_model_checkpoint.pth
# Epoch 51/60 | Loss: 0.3306 | Acc: 0.7588 | LR: 0.000020
# Epoch 52/60 | Loss: 0.3330 | Acc: 0.7832 | LR: 0.000016
# Epoch 53/60 | Loss: 0.3088 | Acc: 0.8354 | LR: 0.000013
# Epoch 54/60 | Loss: 0.3164 | Acc: 0.7811 | LR: 0.000010
# Epoch 55/60 | Loss: 0.2842 | Acc: 0.8168 | LR: 0.000007
# Epoch 56/60 | Loss: 0.2936 | Acc: 0.8684 | LR: 0.000005
# Epoch 57/60 | Loss: 0.3045 | Acc: 0.8189 | LR: 0.000003
# Epoch 58/60 | Loss: 0.3015 | Acc: 0.8052 | LR: 0.000002
# Epoch 59/60 | Loss: 0.3001 | Acc: 0.7818 | LR: 0.000001
# Epoch 60/60 | Loss: 0.3056 | Acc: 0.7883 | LR: 0.000001
# Checkpoint saved: final_model_checkpoint.pth
#   Backed up to Drive: final_model_checkpoint.pth
#
# Final model training time: 1535.46s
#   Backed up to Drive: final_model_checkpoint.pth
# Final model saved to: /content/drive/MyDrive/colab/vit_fungi/output/standard/final_model_standard.pth
# Training curves saved to: /content/drive/MyDrive/colab/vit_fungi/output/standard/final_model_training_curves_standard.png
# ----------------------------------------------------------------------
# FINAL TRAINING COMPLETE
# ----------------------------------------------------------------------
#
# ======================================================================
# PHASE: TEST SET EVALUATION
# ======================================================================
#
#   Loading final model from final_model_standard.pth
#   Model loaded successfully
#   Running inference on 821 test samples...
#   Inference complete
#
#   Computing image-level metrics...
#   Calculating 95% confidence intervals (1000 bootstrap) - image level...
